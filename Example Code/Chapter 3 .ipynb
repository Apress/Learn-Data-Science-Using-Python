# %% [markdown]
# ## Listing 3.1 Scatter plot

# %%
#Listing 3.1.1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Listing 3.1.2
df=pd.read_csv('../Datasets/Chapter 3/City_of_Seattle_Wages__Comparison_by_Gender_-_Average_Hourly_Wage_by_Age.csv')
print(df.head())
# Out:
#   AGE RANGE  Average of FEMALE HOURLY RATE  Count of FEMALE EMPLID  \
# 0   20 - 25                          22.92                      26
# 1   26 - 30                          29.90                     163
# 2   31 - 35                          31.43                     292
# 3   36 - 40                          34.90                     376
# 4   41 - 45                          36.05                     498
#
#    Average of MALE HOURLY RATE  Count of MALE EMPLID  \
# 0                        26.30                    63
# 1                        31.64                   325
# 2                        35.54                   530
# 3                        37.10                   726
# 4                        39.28                   985
#
#    Total Average of HOURLY RATE  Total Count of EMPLID  Female to male % rate
# 0                         25.32                     89                  87.16
# 1                         31.06                    488                  94.50
# ...

# %%
#Listing 3.1.3
print(df.describe())
# Out:
#        Average of FEMALE HOURLY RATE  Count of FEMALE EMPLID  \
# count                      13.000000               13.000000
# mean                       31.956923              553.846154
# std                         6.236531              943.730439
# min                        15.760000                1.000000
# 25%                        30.800000               75.000000
# 50%                        34.900000              369.000000
# 75%                        36.050000              562.000000
# max                        37.190000             3600.000000
#
#        Average of MALE HOURLY RATE  Count of MALE EMPLID  \
# count                    13.000000             13.000000
# mean                     35.443846            966.923077
# std                       7.942968           1645.390656
# min                      13.430000              1.000000
# 25%                      34.520000            131.000000
# 50%                      39.040000            530.000000
# ...

# %%
#Listing 3.1.4
plt.figure(figsize=(12, 6))
plt.scatter(df['AGE RANGE'], df['Total Average of HOURLY RATE'])
plt.xlabel('AGE RANGE')
plt.ylabel('Total Average of HOURLY RATE')
# Out:
# Text(0, 0.5, 'Total Average of HOURLY RATE')

# %%
#Listing 3.1.5
plt.figure(figsize=(12, 6))
df1=df['AGE RANGE']
df2=df['Total Average of HOURLY RATE']
plt.scatter(df1[:-2],df2[:-2] )
plt.xlabel('AGE RANGE')
plt.ylabel('Total Average of HOURLY RATE')
plt.title('Interdependence between Age Range and Total Average of HOURLY RATE')
# Out:
# Text(0.5, 1.0, 'Interdependence between Age Range and Total Average of HOURLY RATE')

# %% [markdown]
# ## Listing 3.2 Plotting More Than One Scatterplot in the Same Image

# %%
#Listing 3.2.1
df=pd.read_excel('../Datasets/Chapter 3/MAINECOUNTIESPARTIES.xlsx')
print(df.head())
# Out:
#        counties  Republican  Democratic
# 0  Androscoggin       28189       22975
# 1     Aroostook       19419       13377
# 2    Cumberland       57697      102935
# 3      Franklin        7900        7001
# 4       Hancock       13682       16107

# %%
#Listing 3.2.2
plt.figure(figsize=(18, 6))
plt.scatter(df['counties'],df['Democratic'], c=['b'])
plt.scatter(df['counties'],df['Republican'] , marker='^',c=['r'])

plt.xlabel('counties')
plt.ylabel('Republican:Red Triangles Democrat:Blue Circles')
plt.title('Maine Counties and Parties')
# Out:
# Text(0.5, 1.0, 'Maine Counties and Parties')

# %% [markdown]
# ## Listing 3.3 Histogram

# %%
#Listing 3.3.1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv('../Datasets/Chapter 3/City_Employee_Salaries_March_2018.csv')
print(df.head())
# Out:
#                      Name   Unit                   Dept            Job_Title  \
# 0         Jones,Marcus D.  CTMGR  City Manager's Office         City Manager
# 1       Hagemann,Robert E  ATTOR          City Attorney        City Attorney
# 2         Lewis Jr,John M   CATS              Executive    Transit  Director
# 3           Cagle,Brent D   AVIA      Admin - Executive    Aviation Director
# 4  Joy-Hogg,Sabrina Beena  CTMGR  City Manager's Office  Deputy City Manager
#
#    Annual_Rt  Hrly_Rate Full_Part Reg_Temp  FID
# 0  318000.00     152.88         F        R    1
# 1  248491.82     119.47         F        R    2
# 2  245924.30     118.23         F        R    3
# 3  236042.01     113.48         F        R    4
# 4  225500.00     108.41         F        R    5

# %%
#Listing 3.3.2
plt.figure(figsize=(18, 10))
plt.hist(df['Annual_Rt'])
plt.xlabel('Annual_Rt')

plt.title('The Distribution of The Annual Rate of Charlotte City Employees')
# Out:
# Text(0.5, 1.0, 'The Distribution of The Annual Rate of Charlotte City Employees')

# %%
#Listing 3.3.3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

plt.figure(figsize=(15, 10))

x = np.arange(0, 140000, 1)

ar = df['Annual_Rt']
mask = ar < 140000
df1 = ar[mask]

plt.hist(df1, bins=10, density=True, alpha=0.6, color='b')

mu, std = norm.fit(df1)
plt.plot(x, norm.pdf(x, mu, std), 'r-', label='Normal Distribution')

plt.xlabel('Annual_Rt')
plt.title('The Distribution of The Annual Rate of Charlotte City Employees')
plt.legend()

plt.show()

# %% [markdown]
# ## Listing 3.4 Series Plot

# %%
#Listing 3.4.1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

stock_symbol = "AAPL"  
start_date = "2022-01-01"
end_date = "2023-01-01"

stock_data = yf.download(stock_symbol, start=start_date, end=end_date)

plt.figure(figsize=(15, 8))
plt.plot(stock_data['Close'], label=f"{stock_symbol} Closing Prices", color='blue')
plt.title(f"{stock_symbol} Closing Prices Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#Listing 3.4.2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

stock_symbols = ["AAPL", "INTC", "MSFT", "ASML"]
start_date = "2021-01-01"
end_date = "2023-01-01"

stock_data = yf.download(stock_symbols, start=start_date, end=end_date)['Close']

plt.figure(figsize=(15, 8))

for symbol in stock_symbols:
    plt.plot(stock_data[symbol], label=f"{symbol} Closing Prices")

plt.title("Closing Prices Over Time for Selected Stocks")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %% [markdown]
# ## Listing 3.5 Bar Chart

# %%
#Listing 3.5.1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Borough = ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
crimes = [50153, 67489, 56691, 44137, 10285]

plt.figure(figsize=(10, 6))
plt.bar(Borough, crimes, color='skyblue')

plt.xlabel('Borough')
plt.ylabel('Number of Crimes')
plt.title('Number of Crimes in Different Boroughs')

plt.show()

# %% [markdown]
# ## Listing 3.5.2 HOW TO SORT A BAR CHART?

# %%
#Listing 3.5.2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Borough = ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
crimes = [50153, 67489, 56691, 44137, 10285]

sorted_data = sorted(zip(Borough, crimes), key=lambda x: x[1])

sorted_Borough, sorted_crimes = zip(*sorted_data)

plt.figure(figsize=(10, 6))
plt.bar(sorted_Borough, sorted_crimes, color='skyblue')

plt.xlabel('Borough')
plt.ylabel('Number of Crimes')
plt.title('Number of Crimes in Different Boroughs (Sorted)')

plt.show()

# %%
#Listing 3.5.3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Borough = ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
crimes = [50153, 67489, 56691, 44137, 10285]

sorted_data = sorted(zip(Borough, crimes), key=lambda x: x[1], reverse=True)

sorted_Borough, sorted_crimes = zip(*sorted_data)

plt.figure(figsize=(10, 6))
plt.bar(sorted_Borough, sorted_crimes, color='skyblue')

plt.xlabel('Borough')
plt.ylabel('Number of Crimes')
plt.title('Number of Crimes in Different Boroughs (Sorted Descending)')

plt.show()

# %%
#Listing 3.5.4
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

Borough = ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']
crimes = [50153, 67489, 56691, 44137, 10285]

sorted_data = sorted(zip(Borough, crimes), key=lambda x: x[1], reverse=True)

sorted_Borough, sorted_crimes = zip(*sorted_data)

plt.figure(figsize=(10, 6))
plt.barh(sorted_Borough, sorted_crimes, color='skyblue')

plt.xlabel('Number of Crimes')
plt.ylabel('Borough')
plt.title('Number of Crimes in Different Boroughs (Horizontal Bar Chart)')

plt.show()

# %% [markdown]
# ## Listing 3.6 CREATE A HISTOGRAM USING A BAR CHART

# %%
#Listing 3.6
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

candidates = ['Obama', 'Romney', 'Johnson', 'Stein', 'Paul', 'Anderson', 'Reed']
winning_percentages = [56.27, 40.98, 1.31, 1.14, 0.29, 0.01, 0]

colors = ['blue', 'red', 'silver', 'green', 'grey', 'grey', 'grey']

plt.figure(figsize=(10, 6))
bars = plt.bar(candidates, winning_percentages, color=colors)

for bar, label in zip(bars, winning_percentages):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.05, bar.get_height() + 0.2, f'{label:.2f}%', ha='center', va='bottom', color='black', fontweight='bold')

plt.xlabel('Candidates')
plt.ylabel('Winning Percentages (%)')
plt.title('Winning Percentages of Presidential Candidates')

plt.show()

# %% [markdown]
# ## Listing 3.7 BUBBLE CHART

# %%
#Listing 3.7.1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)  

students_data = {
    'Name': [f'Student{i}' for i in range(1, 21)],
    'Height': np.random.uniform(150, 190, 20),  
    'Weight': np.random.uniform(45, 90, 20),   
    'Age': np.random.randint(18, 25, 20)       
}

students_df = pd.DataFrame(students_data)

plt.figure(figsize=(12, 8))

scaling_factor = 500

scatter = plt.scatter(students_df['Height'], students_df['Weight'], s=students_df['Age'] * scaling_factor, c=students_df['Age'], cmap='viridis', alpha=0.7)

for i, name in enumerate(students_df['Name']):
    plt.text(students_df['Height'][i], students_df['Weight'][i], name, ha='center', va='center', fontsize=8, color='black', alpha=0.7)

plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Bubble Chart: Height vs Weight with Age as Bubble Size and Student Names')

cbar = plt.colorbar(scatter)
cbar.set_label('Age (years)')

plt.show()

# %%
#Listing 3.7.2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)  

students_df = pd.read_excel('../Datasets/Chapter 3/class.xlsx')
print(students_df.head())

plt.figure(figsize=(25, 20))

scaling_factor = 500

scatter = plt.scatter(students_df['Height'], students_df['Weight'], s=students_df['Age'] * scaling_factor, c=students_df['Age'], cmap='viridis', alpha=0.7)

for i, name in enumerate(students_df['Name']):
    plt.text(students_df['Height'][i], students_df['Weight'][i], name, ha='center', va='center', fontsize=8, color='black', alpha=0.7)

plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Bubble Chart: Height vs Weight with Age as Bubble Size and Student Names')

cbar = plt.colorbar(scatter)
cbar.set_label('Age (years)')

plt.show()
# Out:
#    No       Name      Height     Weight  Age
# 0  10  Student11  170.990257  72.339518   19
# 1   6   Student7  178.322903  49.395245   18
# 2   5   Student6  156.239781  80.332918   23
# 3   4   Student5  156.240746  65.523149   20
# 4  14  Student15  161.649166  64.806862   17
